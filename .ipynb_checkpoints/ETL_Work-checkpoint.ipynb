# %%
import pandas as pd
import numpy as np
import sqlalchemy
import psycopg2
from sqlalchemy import create_engine, func

# %%
games = pd.read_csv("C:/Users/jadev/UCD/Homework/ETL_Project/video_games.txt")
meta = pd.read_csv("C:/Users/jadev/UCD/Homework/ETL_Project/archive.zip")

# %%
games.head()
# Out:
#    number                            game  release_date  price  \
# 0       1                     Half-Life 2  Nov 16, 2004   9.99
# 1       3          Counter-Strike: Source   Nov 1, 2004   9.99
# 2      21  Counter-Strike: Condition Zero   Mar 1, 2004   9.99
# 3      47         Half-Life 2: Deathmatch   Nov 1, 2004   4.99
# 4      36               Half-Life: Source   Jun 1, 2004   9.99
#
#                      owners developer publisher  average_playtime  \
# 0  10,000,000 .. 20,000,000     Valve     Valve             110.0
# 1  10,000,000 .. 20,000,000     Valve     Valve             236.0
# 2  10,000,000 .. 20,000,000     Valve     Valve              10.0
# 3   5,000,000 .. 10,000,000     Valve     Valve               0.0
# 4    2,000,000 .. 5,000,000     Valve     Valve               0.0
#
#    median_playtime  metascore
# 0             66.0       96.0
# 1            128.0       88.0
# 2              3.0       65.0
# 3              0.0        NaN
# 4              0.0        NaN

# %%
meta.head()
# Out:
#    metascore                name console userscore          date
# 0         97  Grand Theft Auto V     PS3       8.3  Sep 17, 2013
# 1         97  Grand Theft Auto V    X360       8.3  Sep 17, 2013
# 2         95      The Last of Us     PS3       9.2  Jun 14, 2013
# 3         94   BioShock Infinite     PS3       8.5  Mar 26, 2013
# 4         94   BioShock Infinite      PC       8.6  Mar 25, 2013

# %%
games.dtypes
# Out:
# number                int64
# game                 object
# release_date         object
# price               float64
# owners               object
# developer            object
# publisher            object
# average_playtime    float64
# median_playtime     float64
# metascore           float64
# dtype: object

# %%
meta.dtypes
# Out:
# metascore     int64
# name         object
# console      object
# userscore    object
# date         object
# dtype: object

# %%
meta['userscore'] = pd.to_numeric(meta['userscore'],errors='coerce')
meta['date'] = pd.to_datetime(meta['date'])

# %%
meta.head()
# Out:
#    metascore                name console  userscore       date
# 0         97  Grand Theft Auto V     PS3        8.3 2013-09-17
# 1         97  Grand Theft Auto V    X360        8.3 2013-09-17
# 2         95      The Last of Us     PS3        9.2 2013-06-14
# 3         94   BioShock Infinite     PS3        8.5 2013-03-26
# 4         94   BioShock Infinite      PC        8.6 2013-03-25

# %%
games['release_date'] = pd.to_datetime(games['release_date'])

# %%
games.head()
# Out:
#    number                            game release_date  price  \
# 0       1                     Half-Life 2   2004-11-16   9.99
# 1       3          Counter-Strike: Source   2004-11-01   9.99
# 2      21  Counter-Strike: Condition Zero   2004-03-01   9.99
# 3      47         Half-Life 2: Deathmatch   2004-11-01   4.99
# 4      36               Half-Life: Source   2004-06-01   9.99
#
#                      owners developer publisher  average_playtime  \
# 0  10,000,000 .. 20,000,000     Valve     Valve             110.0
# 1  10,000,000 .. 20,000,000     Valve     Valve             236.0
# 2  10,000,000 .. 20,000,000     Valve     Valve              10.0
# 3   5,000,000 .. 10,000,000     Valve     Valve               0.0
# 4    2,000,000 .. 5,000,000     Valve     Valve               0.0
#
#    median_playtime  metascore
# 0             66.0       96.0
# 1            128.0       88.0
# 2              3.0       65.0
# 3              0.0        NaN
# 4              0.0        NaN

# %%
meta_game = meta.rename(columns={'name':'game'})

# %%
meta_game.dtypes
# Out:
# metascore             int64
# game                 object
# console              object
# userscore           float64
# date         datetime64[ns]
# dtype: object

# %%
games.dtypes
# Out:
# number                       int64
# game                        object
# release_date        datetime64[ns]
# price                      float64
# owners                      object
# developer                   object
# publisher                   object
# average_playtime           float64
# median_playtime            float64
# metascore                  float64
# dtype: object

# %%
games_clean = games[games['metascore'].notna()]
games_clean_dup = games_clean.drop_duplicates(subset=['game'])
games_no_null = games_clean_dup.dropna(subset=['game'])
games_score =
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-3bbebd543748> in <module>
#       2 games_clean_dup = games_clean.drop_duplicates(subset=['game'])
#       3 games_no_null = games_clean_dup.dropna(subset=['game'])
# ----> 4 games_score = games_no_null[games_no_null(games_no_null.metascore >=70)]
#
# TypeError: 'DataFrame' object is not callable

# %%
games_score
# Out:
#        number                                             game release_date  \
# 0           1                                      Half-Life 2   2004-11-16
# 1           3                           Counter-Strike: Source   2004-11-01
# 2          21                   Counter-Strike: Condition Zero   2004-03-01
# 6           2  Unreal Tournament 2004: Editor's Choice Edition   2004-03-16
# 7           4                                           DOOM 3   2004-08-03
# ...       ...                                              ...          ...
# 21446    2972                                      SUPER KINKY   2018-07-06
# 23311    5052                       DEEP SPACE WAIFU: NEKOMIMI   2018-12-18
# 23367    5133                                      Hentai Dojo   2018-08-24
# 26038    8118                    Story of Eve - A Hero's Study   2018-10-16
# 26149    8251                              Hentai Case Opening   2018-09-27
#
#        price                    owners                         developer  \
# 0       9.99  10,000,000 .. 20,000,000                             Valve
# 1       9.99  10,000,000 .. 20,000,000                             Valve
# 2       9.99  10,000,000 .. 20,000,000                             Valve
# 6      14.99      500,000 .. 1,000,000                  Epic Games, Inc.
# 7       4.99      500,000 .. 1,000,000                       id Software
# ...      ...                       ...                               ...
# 21446   1.99               0 .. 20,000  Dark Illusions Entertainment LLC
# 23311   1.99               0 .. 20,000               Neko Climax Studios
# 23367   0.49               0 .. 20,000                         RewindApp
# 26038   2.99               0 .. 20,000                     SmallSqurriel
# 26149   0.99               0 .. 20,000                         RewindApp
#
#                               publisher  average_playtime  median_playtime  \
# 0                                 Valve             110.0             66.0
# 1                                 Valve             236.0            128.0
# 2                                 Valve              10.0              3.0
# 6                      Epic Games, Inc.               0.0              0.0
# 7                           id Software               0.0              0.0
# ...                                 ...               ...              ...
# 21446  Dark Illusions Entertainment LLC               0.0              0.0
# 23311               Neko Climax Studios               0.0              0.0
# 23367                         RewindApp               0.0              0.0
# 26038                     SmallSqurriel               0.0              0.0
# 26149                         RewindApp               0.0              0.0
#
#        metascore
# 0           96.0
# 1           88.0
# 2           65.0
# 6           93.0
# 7           87.0
# ...          ...
# 21446       70.0
# 23311       98.0
# 23367       65.0
# 26038       87.0
# 26149       63.0
#
# [2831 rows x 10 columns]

# %%
#I'm looking to buy a PSVita and would like to find the best ones to purchase
meta_ps = meta_game[(meta_game.console=='VITA')]
meta_ps
# Out:
#        metascore                               game console  userscore  \
# 20            88                           Spelunky    VITA        7.9
# 33            87                        Guacamelee!    VITA        8.3
# 36            87                     Rayman Legends    VITA        8.4
# 37            87                           Tearaway    VITA        8.9
# 46            87                     Velocity Ultra    VITA        7.9
# ...          ...                                ...     ...        ...
# 14302         63  Operation Babel: New Tokyo Legacy    VITA        4.0
# 14477         55                A.W.: Phoenix Festa    VITA        4.5
# 15308         58                The Caligula Effect    VITA        7.0
# 15637         39                        Drive Girls    VITA        5.5
# 15644         36                 Tokyo Tattoo Girls    VITA        5.4
#
#             date
# 20    2013-08-27
# 33    2013-04-09
# 36    2013-09-03
# 37    2013-11-22
# 46    2013-07-02
# ...          ...
# 14302 2017-05-16
# 14477 2016-07-26
# 15308 2017-05-02
# 15637 2017-09-08
# 15644 2017-11-14
#
# [255 rows x 5 columns]

# %%
connection_string = 'postgres:class_time@localhost:5432/etl-challenge'
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['games', 'meta_game']

# %%
games_no_null.to_sql(name='games', con = engine, if_exists = 'append',index=False)

# %%
meta_ps.to_sql(name='meta_game', con = engine, if_exists = 'append',index=False)
# Out:
# ---------------------------------------------------------------------------
# ForeignKeyViolation                       Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#
# ForeignKeyViolation: insert or update on table "meta_game" violates foreign key constraint "meta_game_game_fkey"
# DETAIL:  Key (game)=(Guacamelee!) is not present in table "games".
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-21-98be364b7bd5> in <module>
# ----> 1 meta_ps.to_sql(name='meta_game', con = engine, if_exists = 'append',index=False)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2603         from pandas.io import sql
#    2604
# -> 2605         sql.to_sql(
#    2606             self,
#    2607             name,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     587         )
#     588
# --> 589     pandas_sql.to_sql(
#     590         frame,
#     591         name,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1404                 raise ValueError("inf cannot be used with MySQL") from err
#    1405             else:
# -> 1406                 raise err
#    1407
#    1408         if not name.isdigit() and not name.islower():
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1396
#    1397         try:
# -> 1398             table.insert(chunksize, method=method)
#    1399         except exc.SQLAlchemyError as err:
#    1400             # GH34431
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     828
#     829                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 830                 exec_insert(conn, keys, chunk_iter)
#     831
#     832     def _query_iterator(
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     745         """
#     746         data = [dict(zip(keys, row)) for row in data_iter]
# --> 747         conn.execute(self.table.insert(), data)
#     748
#     749     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1122             )
#    1123
# -> 1124         ret = self._execute_context(
#    1125             dialect,
#    1126             dialect.execution_ctx_cls._init_compiled,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1314
#    1315         except BaseException as e:
# -> 1316             self._handle_dbapi_exception(
#    1317                 e, statement, parameters, cursor, context
#    1318             )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1508                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1509             elif should_wrap:
# -> 1510                 util.raise_(
#    1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1254                             break
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#    1258                     )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     896     def do_executemany(self, cursor, statement, parameters, context=None):
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#     900
#
# IntegrityError: (psycopg2.errors.ForeignKeyViolation) insert or update on table "meta_game" violates foreign key constraint "meta_game_game_fkey"
# DETAIL:  Key (game)=(Guacamelee!) is not present in table "games".
#
# [SQL: INSERT INTO meta_game (metascore, game, console, userscore, date) VALUES (%(metascore)s, %(game)s, %(console)s, %(userscore)s, %(date)s)]
# [parameters: ({'metascore': 88, 'game': 'Spelunky', 'console': 'VITA', 'userscore': 7.9, 'date': datetime.datetime(2013, 8, 27, 0, 0)}, {'metascore': 87, 'game': 'Guacamelee!', 'console': 'VITA', 'userscore': 8.3, 'date': datetime.datetime(2013, 4, 9, 0, 0)}, {'metascore': 87, 'game': 'Rayman Legends', 'console': 'VITA', 'userscore': 8.4, 'date': datetime.datetime(2013, 9, 3, 0, 0)}, {'metascore': 87, 'game': 'Tearaway', 'console': 'VITA', 'userscore': 8.9, 'date': datetime.datetime(2013, 11, 22, 0, 0)}, {'metascore': 87, 'game': 'Velocity Ultra', 'console': 'VITA', 'userscore': 7.9, 'date': datetime.datetime(2013, 7, 2, 0, 0)}, {'metascore': 90, 'game': 'Velocity 2X', 'console': 'VITA', 'userscore': 7.2, 'date': datetime.datetime(2014, 9, 2, 0, 0)}, {'metascore': 85, 'game': 'Hotline Miami', 'console': 'VITA', 'userscore': 8.4, 'date': datetime.datetime(2013, 6, 25, 0, 0)}, {'metascore': 85, 'game': 'Terraria', 'console': 'VITA', 'userscore': 8.0, 'date': datetime.datetime(2013, 12, 17, 0, 0)}  ... displaying 10 of 255 total bound parameter sets ...  {'metascore': 39, 'game': 'Drive Girls', 'console': 'VITA', 'userscore': 5.5, 'date': datetime.datetime(2017, 9, 8, 0, 0)}, {'metascore': 36, 'game': 'Tokyo Tattoo Girls', 'console': 'VITA', 'userscore': 5.4, 'date': datetime.datetime(2017, 11, 14, 0, 0)})]
# (Background on this error at: http://sqlalche.me/e/13/gkpj)
